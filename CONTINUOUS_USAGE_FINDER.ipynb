# %% [markdown]
# # Continuous Usage Discovery
#
# Goal: Quick script that can find continuous usage of a resource in a given time period.
#
# #### Parameters

# %%
customerName = 'Honeywell'

# bounding dates
startDate = '2023-11-01'
endDate = '2024-05-01'

# analysis parameters
params = {
    "Lighting": {"percent_of_peak": 0.5, "min_length_hours": 48}, 
    "HVAC": {"percent_of_peak": 0.5, "min_length_hours": 48},
    "Other": {"percent_of_peak": 0.5, "min_length_hours": 48}
}

# %% [markdown]
# ### Imports and Initializations

# %%
import pandas as pd
import datetime as dt

from redaptipy.db_clients import rdp_db_client
from redaptipy.api_clients import rdp_partner_api_client

from plotly import graph_objects as go

rdp_client = rdp_db_client.RdpDBClient()
rdp_api_client = rdp_partner_api_client.RdpApiClient()

# %% [markdown]
# ### Asset Selection

# %%
q = """SELECT c.id, 
              c.description,
              p.name as panel_name,
              m.verified_date,
              bs.name as building_system,
              s.address1,
                s.city,
                s.state,
                s.timezone
 FROM circuit c
JOIN building_system bs ON c.building_system_id = bs.id
JOIN panel p ON c.panel_id = p.id
JOIN meter m ON c.meter_id = m.id
JOIN site s ON c.site_id = s.id
JOIN customer cu ON s.customer_id = cu.id
WHERE cu.name = 'Honeywell'
and bs.name not in ('Other', 'Other Submetered', 'Panel Feed', 'Main Panel', 'Main Feed', 'Transformer')
and (c.description not ilike '%exit%' 
    and c.description not ilike '%emergency%' 
    and c.description not ilike '%egress%' 
    and c.description not ilike '%security%')
and c.description is not null"""

# %%
circuits = rdp_client.query(q).set_index('id')

# %% [markdown]
# ### Data Download

# %%
df = rdp_api_client.get_data_by_circuit(
    circuit_ids=circuits.index.to_list(), 
    start_date=dt.datetime.strptime(startDate, '%Y-%m-%d'),
    end_date=dt.datetime.strptime(endDate, '%Y-%m-%d'),
    resolution=15,
    power_parameter='activePower'
    )

df.to_csv('co_data.csv')

# %% [markdown]
# ### Analysis

# %%
equipment_df = df.groupby([circuits['address1'], 
                           circuits['description'],
                           circuits['building_system'], 
                           circuits['timezone'],
                           circuits['verified_date']], axis=1).sum()

# %%
blocks_df = pd.DataFrame()

for c in equipment_df.columns:
    site, equipment_name, system, timezone, metering_start = c[0], c[1], c[2], c[3], c[4]
    system_params = params.get(system, params['Other'])
    percent_of_peak = system_params['percent_of_peak']
    min_length_hours = system_params['min_length_hours']    

    equipment = equipment_df[c][metering_start:]
    equipment = equipment.tz_localize('UTC').tz_convert(timezone).tz_localize(None)
    
    
    thresholded = equipment_df[c] / equipment_df[c].quantile(.99) > percent_of_peak
    blocks = thresholded.diff().abs().cumsum()
    matches = blocks.mask(~thresholded, 0)
    
    blocks = pd.DataFrame(data={'length':matches.groupby(matches).count() * 15,
                                'start':matches.groupby(matches).apply(lambda s: s.index[0]),
                                'max': equipment_df[c].max()})
    blocks = blocks[blocks.length > (min_length_hours*60)]
    blocks = blocks.drop(0, errors='ignore')

    fig = go.Figure()

    figStart = pd.to_datetime('2025-01-01')
    figEnd = pd.to_datetime('2020-01-01')

    print(f'{site} - {equipment_name} - {system}')
    print(blocks.shape[0])
    if blocks.shape[0] > 0:
        for i, block in blocks.iterrows():
            if block['max'] < 1: continue
            block_info = {'site': site,
                          'equipment': equipment_name,
                          'building_system': system,
                          'length': block['length'],
                          'start': block['start'],
                          'end': block['start'] + pd.Timedelta(seconds=60*block['length']),
                          'verified_date': metering_start
                          }

            insert_index = len(blocks_df)
            for k, v in block_info.items():
                blocks_df.loc[insert_index, k] = v
                blocks_df.loc[insert_index, 'max_usage_in_block'] = equipment_df[block_info['start']:block_info['end']][c].max()
                blocks_df.loc[insert_index, 'avg_usage_in_block'] = equipment_df[block_info['start']:block_info['end']][c].mean()
                blocks_df.loc[insert_index, 'total_usage_in_block'] = equipment_df[block_info['start']:block_info['end']][c].sum()/4
                blocks_df.loc[insert_index, 'avg_usage'] = equipment_df[c].mean()
                blocks_df.loc[insert_index, 'max_usage'] = equipment_df[c].max()
                blocks_df.loc[insert_index, 'total_usage'] = equipment_df[c].sum()/4
                blocks_df.loc[insert_index, 'block_percentage_of_use'] = blocks_df.loc[insert_index, 'total_usage_in_block'] / blocks_df.loc[insert_index, 'total_usage']

            figStart = min(figStart, block_info['start'])
            figEnd = max(figEnd, block_info['start'] + pd.Timedelta(seconds=60*block_info['length']))

            fig.add_shape(type='rect',
                        x0=block_info['start'],
                        y0=0,
                        x1=block_info['end'],
                        y1=equipment_df[block_info['start']:block_info['end']][c].max(),
                        line=dict(width=0),
                        fillcolor='red',
                        opacity=0.5)

        fig.add_scatter(x=matches[figStart:figEnd].index, y=equipment_df[figStart:figEnd][c])

        fig.update_layout(template='simple_white')
        fig.update_xaxes(title='Time')
        fig.update_yaxes(title='Power (kW)')
        
        fig.write_html(f'Honeywell/continuousUsageCharts/{site}_{equipment_name.replace("/","").strip()}.html')
# Out:
#  Fire-Lite Place -  Variable Air volume 5 - PLP2 - HVAC
# 0
#  Fire-Lite Place - 11 High Bay Lighting - HP-G15 - Lighting
# 4
#  Fire-Lite Place - 24 Volts Output by Red Stripped Battery Chargers - HVP-1 - Plug Load
# 1
#  Fire-Lite Place - 480v Twist Lock Column Outlet - HVP-1 - Distribution Center Area - Plug Load
# 0
#  Fire-Lite Place - 9 High Bay Lighting - HP-G15 - Lighting
# 12
#  Fire-Lite Place - Air Compressor - HP-N17 - HVAC
# 1
#  Fire-Lite Place - Air Handling Unit Rooftop #40 Office - HVAC - HVAC
# 0
#  Fire-Lite Place - Air Handling Unit Rooftop #42 Office - HVAC - HVAC
# 1
#  Fire-Lite Place - Air Handling Unit Rooftop High Bay #31 - HVAC - HVAC
# 0
#  Fire-Lite Place - Air Handling Unit Rooftop High Bay #33 - HVAC - HVAC
# 5
#  Fire-Lite Place - Air Handling Unit Rooftop High Bay #34 - HVAC - HVAC
# 1
#  Fire-Lite Place - Air Handling Unit Rooftop Low Bay #35 - HVAC - HVAC
# 0
#  Fire-Lite Place - Air Handling Unit Rooftop Low Bay #37 - HVAC - HVAC
# 0
#  Fire-Lite Place - Air Handling Unit Rooftop Low Bay #38 - HVAC - HVAC
# 0
#  Fire-Lite Place - Bathroom Heaters - HVP-1 - HVAC
# 5
#  Fire-Lite Place - Bathroom Lighting - HVP-1 - Distribution Center Area - Plug Load
# 0
#  Fire-Lite Place - Bathroom Lighting - PLP2 - Lighting
# 0
#  Fire-Lite Place - Bathroom and Storeroom Lighting - HVP-1 - Lighting
# 23
#  Fire-Lite Place - Battery Charger - HVP-1 - Distribution Center Area - Plug Load
# 0
#  Fire-Lite Place - Battery Charger I2 - HVP-1 - Distribution Center Area - Plug Load
# 0
#  Fire-Lite Place - Battery Chargers - HVP-1 - Plug Load
# 1
#  Fire-Lite Place - Boiler Feed - HP-M18 - HVAC
# 1
#  Fire-Lite Place - Breaker 24 - HP-G15 - Lighting
# 12
#  Fire-Lite Place - Breaker 26 - HP-G15 - Lighting
# 12
#  Fire-Lite Place - Cafe Lighting - HVP-1 - Distribution Center Area - Lighting
# 0
#  Fire-Lite Place - Cafe Lightings - PLP1 - Lighting
# 5
#  Fire-Lite Place - Circulator #1 Hot Water Heater - HP-M18 - HVAC
# 7
#  Fire-Lite Place - Circulator #2 Hot Water Heater - HP-M18 - HVAC
# 0
#  Fire-Lite Place - Demo Room - EV Manager - Lighting - HP-B9 - Lighting
# 0
#  Fire-Lite Place - EV Lab, Gamewell Training Room - Lighting - HP-B9 - Lighting
# 0
#  Fire-Lite Place - East Night Lighting - A - Lighting
# 0
#  Fire-Lite Place - East Side Office Lighting - PLP2 - Lighting
# 0
#  Fire-Lite Place - East Side Rear Office Lighting - PLP2 - Lighting
# 0
#  Fire-Lite Place - Electric & Phone Room Lighting - PLP1 - Lighting
# 0
#  Fire-Lite Place - Electric Heat Entrance Personnel Office - HP-G15 - HVAC
# 0
#  Fire-Lite Place - Electrical Room Lighting - HV-PR - Lighting
# 0
#  Fire-Lite Place - Electrical Room Row 2 Lighting - HV-PR - Lighting
# 0
#  Fire-Lite Place - Elevator Pump - EPLP2 - Process Equipment
# 0
#  Fire-Lite Place - Employees East Entrance Heater - Heat panel - HVAC
# 0
#  Fire-Lite Place - Entrance Lighting - HP-G15 - Lighting
# 0
#  Fire-Lite Place - Enviro Chiller - A - HVAC
# 0
#  Fire-Lite Place - Executive Office Lighting - EPLP2 - Lighting
# 0
#  Fire-Lite Place - Exhaust Fans for Spray Booths - HP-Q5 - HVAC
# 0
#  Fire-Lite Place - Final Assembly 8' Lighting - HVP-2 - Lighting
# 13
#  Fire-Lite Place - Finance - Lighting - HP-B9 - Lighting
# 0
#  Fire-Lite Place - Finance Gamewell Training - Lighting - HP-B9 - Lighting
# 3
#  Fire-Lite Place - Finished Goods Storage 2 Rear Offices Lighting - HP-G15 - Lighting
# 13
#  Fire-Lite Place - Fluorescent Lighting Stock Area - HP-N17 - Lighting
# 13
#  Fire-Lite Place - Garage Door Metal Scrap - HVP-2 - Process Equipment
# 3
#  Fire-Lite Place - High Bay 3 Lighting - HP-G15 - Lighting
# 7
#  Fire-Lite Place - High Bay East Row 1 Lighting - HVP-1 - Lighting
# 0
#  Fire-Lite Place - High Bay Row 2 Lighting - HVP-1 - Lighting
# 0
#  Fire-Lite Place - High Bay Row 3 Lighting - HVP-1 - Lighting
# 12
#  Fire-Lite Place - Row Number 19 Lighting - HP-G9 - Lighting
# 12
#  Fire-Lite Place - Row Number 20 Lighting - HP-G9 - Lighting
# 12
#  Fire-Lite Place - Row Number 24 Lighting - HP-G9 - Lighting
# 11
#  Fire-Lite Place - Row Southwest Lighting - A - Lighting
# 0
#  Fire-Lite Place - Row no. 1 Lighting - HP-G15 - Lighting
# 7
#  Fire-Lite Place - Row no. 10 Print Shop Lighting - HP-G15 - Lighting
# 0
#  Fire-Lite Place - Row no. 11 Lighting - HP-G15 - Lighting
# 0
#  Fire-Lite Place - Row no. 12 Lighting - HP-G15 - Lighting
# 0
#  Fire-Lite Place - Row no. 13 Lighting - HP-G15 - Lighting
# 1
#  Fire-Lite Place - Row no. 14 Lighting - HP-G15 - Lighting
# 0
#  Fire-Lite Place - Row no. 15 Lighting - HP-G15 - Lighting
# 12
#  Fire-Lite Place - Row no. 2 Lighting - HP-G15 - Lighting
# 12
#  Fire-Lite Place - Row no. 3 Print Shop Lighting - HP-G15 - Lighting
# 12
#  Fire-Lite Place - Row no. 4 Storage Lighting - HP-G15 - Lighting
# 0
#  Fire-Lite Place - Row no. 5 Storage Lighting - HP-G15 - Lighting
# 0
#  Fire-Lite Place - Row no. 6 Storage High Bay Lighting - HP-G15 - Lighting
# 12
#  Fire-Lite Place - Row no. 7 High Bay Lighting - HP-G15 - Lighting
# 12
#  Fire-Lite Place - Row no. 8 Lighting - HP-G15 - Lighting
# 12
#  Fire-Lite Place - Row no. 9 Print Shop Lighting - HP-G15 - Lighting
# 12
#  Fire-Lite Place - Shipping Conveyor not in use - HP-N17 - Process Equipment
# 0
#  Fire-Lite Place - Silk Screen Department Lighting - HP-Q5 - Lighting
# 1
#  Fire-Lite Place - Silk Screen Lighting - HP-Q5 - Lighting
# 12
#  Fire-Lite Place - South Front Office Lighting - PLP2 - Lighting
# 0
#  Fire-Lite Place - Time Clock, Parking Lot and Building Lighting - HP-M18 - Lighting
# 0
#  Fire-Lite Place - Training Laboratory Lighting - PLP1 - Lighting
# 0
#  Fire-Lite Place - Training Storage & Back Offices Lighting - PLP1 - Lighting
# 0
#  Fire-Lite Place - Transformer  Assembly 8' Lighting - HVP-2 - Lighting
# 3
#  Fire-Lite Place - Transformer Assembly 8' Lighting - HVP-2 - Lighting
# 1
#  Fire-Lite Place - Variable Air volume 1 - EPLP2 - HVAC
# 0
#  Fire-Lite Place - Variable Air volume 1, Variable Air volume 43 - 9 - PLP1 - HVAC
# 0
#  Fire-Lite Place - Variable Air volume 10 - EPLP2 - HVAC
# 0
#  Fire-Lite Place - Variable Air volume 11 - PLP2 - HVAC
# 0
#  Fire-Lite Place - Variable Air volume 12 - PLP2 - HVAC
# 0
#  Fire-Lite Place - Variable Air volume 13 - PLP2 - HVAC
# 0
#  Fire-Lite Place - Variable Air volume 14 - PLP2 - HVAC
# 0
#  Fire-Lite Place - Variable Air volume 14, Variable Air volume 49 - 6 - PLP1 - HVAC
# 0
#  Fire-Lite Place - Variable Air volume 15 - PLP1 - HVAC
# 0
#  Fire-Lite Place - Variable Air volume 15 - PLP2 - HVAC
# 0
#  Fire-Lite Place - Variable Air volume 16 - EPLP2 - HVAC
# 0
#  Fire-Lite Place - Variable Air volume 16, Variable Air volume 49 - 4 - PLP1 - HVAC
# 0
#  Fire-Lite Place - Variable Air volume 17, Variable Air volume 49 - 3- PLP1 - HVAC
# 0
#  Fire-Lite Place - Variable Air volume 2 - EPLP2 - HVAC
# 0
#  Fire-Lite Place - Variable Air volume 2, Variable Air volume 43 - 8 - PLP1 - HVAC
# 0
#  Fire-Lite Place - Variable Air volume 3 - EPLP2 - HVAC
# 0
#  Fire-Lite Place - Variable Air volume 3, Variable Air volume 43 - 7 - PLP1 - HVAC
# 0
#  Fire-Lite Place - Variable Air volume 4 - EPLP2 - HVAC
# 0
#  Fire-Lite Place - Variable Air volume 4, Variable Air volume 43 - 4 - PLP1 - HVAC
# 0
#  Fire-Lite Place - Variable Air volume 46-1 - EPM 1 - HVAC
# 0
#  Fire-Lite Place - Variable Air volume 46-2 - EPM 1 - HVAC
# 0
#  Fire-Lite Place - Variable Air volume 46-3 - EPM 1 - HVAC
# 0
#  Fire-Lite Place - Variable Air volume 46-4 - EPM 1 - HVAC
# 0
#  Fire-Lite Place - Variable Air volume 49 - 7, 8, 9 - EPM 1 - HVAC
# 1
#  Fire-Lite Place - Variable Air volume 5, Variable Air volume 43 - 3 - PLP1 - HVAC
# 0
#  Fire-Lite Place - Variable Air volume 6 - EPLP2 - HVAC
# 0
#  Fire-Lite Place - Variable Air volume 6, Variable Air volume 43 - 2 - PLP1 - HVAC
# 0
#  Fire-Lite Place - Variable Air volume 7 - EPLP2 - HVAC
# 0
#  Fire-Lite Place - Variable Air volume 7, Variable Air volume 45 - 2 - PLP1 - HVAC
# 6
#  Fire-Lite Place - Variable Air volume 8 - EPLP2 - HVAC
# 0
#  Fire-Lite Place - Variable Air volume 8, Variable Air volume 45 - 1 - PLP1 - HVAC
# 0
#  Fire-Lite Place - Variable Air volume 9 - EPLP2 - HVAC
# 0
#  Fire-Lite Place - Warehouse Lighting - HVP-2 - Lighting
# 0
#  Fire-Lite Place - Warehouse South Aisle Lighting - HVP-2 - Lighting
# 0
#  Fire-Lite Place - Water Heater Above - HP-G15 - HVAC
# 0
#  Fire-Lite Place - West Night Lighting - A - Lighting
# 1
#  Fire-Lite Place - West Side Office Lighting - PLP2 - Lighting
# 0
# 12220 Rojas Drive - Air Conditioner #23 - HD #5 - HVAC
# 1
# 12220 Rojas Drive - Air Conditioner #5 - HD #5 - HVAC
# 0
# 12220 Rojas Drive - Air Conditioner - 1 30 HC - F - HVAC
# 0
# 12220 Rojas Drive - Air Conditioner 03 - C - HVAC
# 0
# 12220 Rojas Drive - Air Conditioner 04 - C - HVAC
# 1
# 12220 Rojas Drive - Air Conditioner 05 - C - HVAC
# 0
# 12220 Rojas Drive - Air Conditioner 06 - C - HVAC
# 0
# 12220 Rojas Drive - Air Conditioner 1 - A - HVAC
# 1
# 12220 Rojas Drive - Air Conditioner 10 - H - HVAC
# 0
# 3825 Ohio Avenue - Smoke Room Lighting - LP1 - Lighting
# 7
# 3825 Ohio Avenue - Sump Pump Water - RTP1 - Process Equipment
# 0
# 3825 Ohio Avenue - Television - PP6 - Plug Load
# 0
# 3825 Ohio Avenue - Thermotron Shaker - BPP18 - Process Equipment
# 0
# 3825 Ohio Avenue - Training Room Lighting - LP1 - Lighting
# 2
# 3825 Ohio Avenue - Warehouse Exhaust Fan - PP1 - HVAC
# 1
# 6060 Rockside Woods Boulevard North - Advent -  HDPD - Tenant Panel
# 0
# 6060 Rockside Woods Boulevard North - Board Room / Office Supplier Lighting - LA - Lighting
# 0
# 6060 Rockside Woods Boulevard North - Breaker 09-11-13 -  HDPD - Tenant Panel
# 3
# 6060 Rockside Woods Boulevard North - Conference Room Lighting - LA - Lighting
# 0
# 6060 Rockside Woods Boulevard North - Equitable Life -  HDPD - Tenant Panel
# 3
# 6060 Rockside Woods Boulevard North - Hardware Lab Lighting -  LA - Lighting
# 1
# 6060 Rockside Woods Boulevard North - Operation Lighting - LA - Lighting
# 0
# 6060 Rockside Woods Boulevard North - PVC Lighting Executive Area/ Accounting - LA - Lighting
# 0
# 6060 Rockside Woods Boulevard North - PVC Lighting Programming/ Marketing - LA - Lighting
# 0
# 6060 Rockside Woods Boulevard North - Training / Lunch Room Lighting - LA - Lighting
# 0
# 65 Shawmut Road - 1st & 2nd Floor General Plugs - L1A - Plug Load
# 0
# 65 Shawmut Road - 1st Floor Bath & Kitchen Plug - L1A - Plug Load
# 2
# 65 Shawmut Road - 1st Floor Bathroom, Electrical, Conference Room Lighting - HL1A - Lighting
# 0
# 65 Shawmut Road - 1st Floor General Plugs - L1A - Plug Load
# 0
# 65 Shawmut Road - 1st Floor High Office Lighting - HL1A - Lighting
# 3
# 65 Shawmut Road - 1st Floor Main Lighting - HL1A - Lighting
# 3
# 65 Shawmut Road - 1st Floor Office Lighting - HL1A - Lighting
# 0
# 65 Shawmut Road - 1st Floor Office Plugs - L1A - Plug Load
# 0
# 65 Shawmut Road - 6 Copy Plugs / Entry Furniture, Exterior Wall Spare - L1B - Plug Load
# 0
# 65 Shawmut Road - Conference Room Plugs - L1A - Plug Load
# 0
# 65 Shawmut Road - Demo Room Plug - L1A - Plug Load
# 0
# 65 Shawmut Road - Dock Plugs - L1B - Plug Load
# 1
# 65 Shawmut Road - Furniture near Training Room - L1B - Plug Load
# 0
# 65 Shawmut Road - General Receptacles - L1B - Plug Load
# 0
# 65 Shawmut Road - Individual Distribution Frame Room Plug - L1B - Plug Load
# 1
# 65 Shawmut Road - Kitchen Ground Fault Interruptor - L1A - Plug Load
# 0
# 65 Shawmut Road - Kitchen Outlet (Dedicated) - L1A - Plug Load
# 0
# 65 Shawmut Road - Men's Exhaust Fan Panel Plug - L1B - Plug Load
# 0
# 65 Shawmut Road - Men's Room Water Heater - L1B - HVAC
# 0
# 65 Shawmut Road - Mezzanine Furniture - L1B - Plug Load
# 0
# 65 Shawmut Road - Mezzanine Furniture Feed - L1A - Plug Load
# 0
# 65 Shawmut Road - Mezzanine Office Furniture - L1A - Plug Load
# 0
# 9901 Linn Station Road - Existing Office Receptacle - Panel B8-1 - Plug Load
# 4
# 9901 Linn Station Road - Focus Room 822 Receptacles - Panel A8-1 - Plug Load
# 0
# 9901 Linn Station Road - Focus Room 823 Receptacles - Panel A8-1 - Plug Load
# 0
# 9901 Linn Station Road - Huddle Room 824 Receptacles - Panel A8-1 - Plug Load
# 0
# 9901 Linn Station Road - Huddle Room 826 Receptacle - Panel A8-1 - Plug Load
# 0
# 9901 Linn Station Road - IGS Area 825 Receptacles - Panel A8-1 - Plug Load
# 0
# 9901 Linn Station Road - Ice Maker - Panel A8-1 - Plug Load
# 0
# 9901 Linn Station Road - Open Office 801 Floor Box - Panel B8-1 - Plug Load
# 1
# 9901 Linn Station Road - Open Office 807 Floor Box - Panel B8-1 - Plug Load
# 2
# 9901 Linn Station Road - Open Office 814 Floor Box - Panel B8-1 - Plug Load
# 4
# 9901 Linn Station Road - Open Office 814 Floor Box 1 - Panel A8-1 - Plug Load
# 0
# 9901 Linn Station Road - Open Office 814 Floor Box 2 - Panel A8-1 - Plug Load
# 0
# 9901 Linn Station Road - Open Office 814 Floor Box 3 - Panel A8-1 - Plug Load
# 0
# 9901 Linn Station Road - Reception Area 800 Receptacles - Panel B8-1 - Plug Load
# 0
# 9901 Linn Station Road - Recording Studio 819 Receptacles - Panel A8-1 - Plug Load
# 0
# 9901 Linn Station Road - Room 800, 801, 802, 803, 804, 805 Lighting - Panel BB8 - Lighting
# 0
# 9901 Linn Station Road - Room 811, 812, 813, 814, 815 Lighting - Panel BB8 - Lighting
# 0
# 9901 Linn Station Road - Room 814, 821, 825, 826, 827 Lighting - Panel AA8 - Lighting
# 0
# 9901 Linn Station Road - Room 816, 817, 818, 819, 820, 822, 823,824 Lighting - Panel AA8 - Lighting
# 0
# 9901 Linn Station Road - Storage Room 817 Receptacles - Panel A8-1 - Plug Load
# 0
# 9901 Linn Station Road - Training Room 815 Floor Box - Panel B8-1 - Plug Load
# 0

# %%
equipment
# Out:
# 2024-02-14 16:30:00    0.0
# 2024-02-14 16:45:00    0.0
# 2024-02-14 17:00:00    0.0
# 2024-02-14 17:15:00    0.0
# 2024-02-14 17:30:00    0.0
#                       ...
# 2024-04-30 19:00:00    0.0
# 2024-04-30 19:15:00    0.0
# 2024-04-30 19:30:00    0.0
# 2024-04-30 19:45:00    0.0
# 2024-04-30 20:00:00    0.0
# Name: (9901 Linn Station Road, Training Room 815 Floor Box - Panel B8-1, Plug Load, America/New_York, 2024-02-14 21:28:07), Length: 7307, dtype: float64

# %% [markdown]
# ## Format and Export

# %%
# convert start and end times to strings
formatted_df = blocks_df[['site',
                          'building_system',
                          'equipment',
                          'verified_date',
                          'length',
                          'start',
                          'end',
                          'max_usage_in_block',
                          'avg_usage_in_block',
                          'total_usage_in_block',
                          'avg_usage',
                          'max_usage',
                          'total_usage',
                          'block_percentage_of_use']]

formatted_df['start'] = formatted_df['start'].dt.strftime('%Y-%m-%d %H:%M:%S')
formatted_df['end'] = formatted_df['end'].dt.strftime('%Y-%m-%d %H:%M:%S')

# convert block length in minutes to days hours minutes
formatted_df['length'] = formatted_df['length'].apply(lambda x: str(dt.timedelta(minutes=x)))

# formatted df rounding
formatted_df = formatted_df.round(2)

# change column names
formatted_df = formatted_df.rename(columns={'site':'Site',
                                            'building_system':'Building System',
                                            'verified_date':'Metering Start',
                                            'equipment':'Equipment',
                                            'length':'Block Length',
                                            'start':'Block Start Time',
                                            'end':'Block End Time',
                                            'max_usage_in_block':'Max Usage in Block (kW)',
                                            'avg_usage_in_block':'Average Usage in Block (kW)',
                                            'total_usage_in_block':'Total Usage in Block (kWh)',
                                            'avg_usage':'Average Usage (kW)',
                                            'max_usage':'Max Usage (kW)',
                                            'total_usage':'Total Usage (kWh)',
                                            'block_percentage_of_use':'Block Percentage of Total Use (%)'
                                            })

portfolio_summary_df = pd.DataFrame(data={
                                    'Count of Unique Equipment': formatted_df.groupby('Site')['Equipment'].nunique(),
                                    'Metering Start': formatted_df.groupby('Site')['Metering Start'].max(),
                                    'Count of Instances': formatted_df.groupby('Site').count()['Building System'],
                                    'Total Usage in Blocks (kWh)': formatted_df.groupby('Site').sum()['Total Usage in Block (kWh)']})

# # export to different sheets in a workbook, one for each site
with pd.ExcelWriter('Honeywell/Honeywell_ContinuousUsage.xlsx') as writer:
    portfolio_summary_df.to_excel(writer, sheet_name='Site Summary')

    for site in formatted_df['Site'].unique():
        site_formatted_df = formatted_df[formatted_df['Site'] == site]

        site_summary_df = pd.DataFrame(data={
                                    'Building System': site_formatted_df.groupby('Equipment').apply(lambda x: x['Building System'].values[0]),
                                    'Metering Start': site_formatted_df.groupby('Equipment').apply(lambda x: x['Metering Start'].values[0]),
                                    'Count of Instances': site_formatted_df.groupby('Equipment').count()['Building System'],
                                    'Total Usage in Blocks (kWh)': site_formatted_df.groupby('Equipment').sum()['Total Usage in Block (kWh)'],
                                    'Total Usage (kWh)': site_formatted_df.groupby('Equipment').sum()['Total Usage (kWh)'],
                                    'Percentage of Total Use in Blocks (%)': (site_formatted_df.groupby('Equipment').sum()['Total Usage in Block (kWh)'] / site_formatted_df.groupby('Equipment').sum()['Total Usage (kWh)']),
                                    'Longest Block': site_formatted_df.groupby('Equipment').max()['Block Length']
                                    })

        site_summary_df.to_excel(writer, sheet_name=site, index=True)

    formatted_df.to_excel(writer, sheet_name='All Instances', index=True)
# Out:
# /var/folders/ld/px3lfl4j771_lns2jvpqcpfr0000gn/T/ipykernel_70128/862417038.py:47: FutureWarning:
#
# The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#
# /var/folders/ld/px3lfl4j771_lns2jvpqcpfr0000gn/T/ipykernel_70128/862417038.py:60: FutureWarning:
#
# The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#
# /var/folders/ld/px3lfl4j771_lns2jvpqcpfr0000gn/T/ipykernel_70128/862417038.py:61: FutureWarning:
#
# The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#
# /var/folders/ld/px3lfl4j771_lns2jvpqcpfr0000gn/T/ipykernel_70128/862417038.py:62: FutureWarning:
#
# The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#
# /var/folders/ld/px3lfl4j771_lns2jvpqcpfr0000gn/T/ipykernel_70128/862417038.py:62: FutureWarning:
#
# The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#
# /var/folders/ld/px3lfl4j771_lns2jvpqcpfr0000gn/T/ipykernel_70128/862417038.py:60: FutureWarning:
#
# The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#
# /var/folders/ld/px3lfl4j771_lns2jvpqcpfr0000gn/T/ipykernel_70128/862417038.py:61: FutureWarning:
#
# The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#
# /var/folders/ld/px3lfl4j771_lns2jvpqcpfr0000gn/T/ipykernel_70128/862417038.py:62: FutureWarning:
#
# The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#
# /var/folders/ld/px3lfl4j771_lns2jvpqcpfr0000gn/T/ipykernel_70128/862417038.py:62: FutureWarning:
#
# The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#
# /var/folders/ld/px3lfl4j771_lns2jvpqcpfr0000gn/T/ipykernel_70128/862417038.py:60: FutureWarning:
#
# The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#
# /var/folders/ld/px3lfl4j771_lns2jvpqcpfr0000gn/T/ipykernel_70128/862417038.py:61: FutureWarning:
#
# The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#
# /var/folders/ld/px3lfl4j771_lns2jvpqcpfr0000gn/T/ipykernel_70128/862417038.py:62: FutureWarning:
#
# The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#
# /var/folders/ld/px3lfl4j771_lns2jvpqcpfr0000gn/T/ipykernel_70128/862417038.py:62: FutureWarning:
#
# The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#
# /var/folders/ld/px3lfl4j771_lns2jvpqcpfr0000gn/T/ipykernel_70128/862417038.py:60: FutureWarning:
#
# The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#
# /var/folders/ld/px3lfl4j771_lns2jvpqcpfr0000gn/T/ipykernel_70128/862417038.py:61: FutureWarning:
#
# The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#
# /var/folders/ld/px3lfl4j771_lns2jvpqcpfr0000gn/T/ipykernel_70128/862417038.py:62: FutureWarning:
#
# The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#
# /var/folders/ld/px3lfl4j771_lns2jvpqcpfr0000gn/T/ipykernel_70128/862417038.py:62: FutureWarning:
#
# The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#
# /var/folders/ld/px3lfl4j771_lns2jvpqcpfr0000gn/T/ipykernel_70128/862417038.py:60: FutureWarning:
#
# The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#
# /var/folders/ld/px3lfl4j771_lns2jvpqcpfr0000gn/T/ipykernel_70128/862417038.py:61: FutureWarning:
#
# The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#
# /var/folders/ld/px3lfl4j771_lns2jvpqcpfr0000gn/T/ipykernel_70128/862417038.py:62: FutureWarning:
#
# The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#
# /var/folders/ld/px3lfl4j771_lns2jvpqcpfr0000gn/T/ipykernel_70128/862417038.py:62: FutureWarning:
#
# The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#
# /var/folders/ld/px3lfl4j771_lns2jvpqcpfr0000gn/T/ipykernel_70128/862417038.py:60: FutureWarning:
#
# The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#
# /var/folders/ld/px3lfl4j771_lns2jvpqcpfr0000gn/T/ipykernel_70128/862417038.py:61: FutureWarning:
#
# The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#
# /var/folders/ld/px3lfl4j771_lns2jvpqcpfr0000gn/T/ipykernel_70128/862417038.py:62: FutureWarning:
#
# The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#
# /var/folders/ld/px3lfl4j771_lns2jvpqcpfr0000gn/T/ipykernel_70128/862417038.py:62: FutureWarning:
#
# The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#
# /var/folders/ld/px3lfl4j771_lns2jvpqcpfr0000gn/T/ipykernel_70128/862417038.py:60: FutureWarning:
#
# The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#
# /var/folders/ld/px3lfl4j771_lns2jvpqcpfr0000gn/T/ipykernel_70128/862417038.py:61: FutureWarning:
#
# The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#
# /var/folders/ld/px3lfl4j771_lns2jvpqcpfr0000gn/T/ipykernel_70128/862417038.py:62: FutureWarning:
#
# The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#
# /var/folders/ld/px3lfl4j771_lns2jvpqcpfr0000gn/T/ipykernel_70128/862417038.py:62: FutureWarning:
#
# The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#
# /var/folders/ld/px3lfl4j771_lns2jvpqcpfr0000gn/T/ipykernel_70128/862417038.py:60: FutureWarning:
#
# The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#
# /var/folders/ld/px3lfl4j771_lns2jvpqcpfr0000gn/T/ipykernel_70128/862417038.py:61: FutureWarning:
#
# The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#
# /var/folders/ld/px3lfl4j771_lns2jvpqcpfr0000gn/T/ipykernel_70128/862417038.py:62: FutureWarning:
#
# The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#
# /var/folders/ld/px3lfl4j771_lns2jvpqcpfr0000gn/T/ipykernel_70128/862417038.py:62: FutureWarning:
#
# The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#
# /var/folders/ld/px3lfl4j771_lns2jvpqcpfr0000gn/T/ipykernel_70128/862417038.py:60: FutureWarning:
#
# The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#
# /var/folders/ld/px3lfl4j771_lns2jvpqcpfr0000gn/T/ipykernel_70128/862417038.py:61: FutureWarning:
#
# The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#
# /var/folders/ld/px3lfl4j771_lns2jvpqcpfr0000gn/T/ipykernel_70128/862417038.py:62: FutureWarning:
#
# The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#
# /var/folders/ld/px3lfl4j771_lns2jvpqcpfr0000gn/T/ipykernel_70128/862417038.py:62: FutureWarning:
#
# The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#
# /var/folders/ld/px3lfl4j771_lns2jvpqcpfr0000gn/T/ipykernel_70128/862417038.py:60: FutureWarning:
#
# The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#
# /var/folders/ld/px3lfl4j771_lns2jvpqcpfr0000gn/T/ipykernel_70128/862417038.py:61: FutureWarning:
#
# The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#
# /var/folders/ld/px3lfl4j771_lns2jvpqcpfr0000gn/T/ipykernel_70128/862417038.py:62: FutureWarning:
#
# The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#
# /var/folders/ld/px3lfl4j771_lns2jvpqcpfr0000gn/T/ipykernel_70128/862417038.py:62: FutureWarning:
#
# The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#
# /var/folders/ld/px3lfl4j771_lns2jvpqcpfr0000gn/T/ipykernel_70128/862417038.py:60: FutureWarning:
#
# The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#
# /var/folders/ld/px3lfl4j771_lns2jvpqcpfr0000gn/T/ipykernel_70128/862417038.py:61: FutureWarning:
#
# The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#
# /var/folders/ld/px3lfl4j771_lns2jvpqcpfr0000gn/T/ipykernel_70128/862417038.py:62: FutureWarning:
#
# The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#
# /var/folders/ld/px3lfl4j771_lns2jvpqcpfr0000gn/T/ipykernel_70128/862417038.py:62: FutureWarning:
#
# The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#
# /Users/chesterhitz/Projects/ptac-data-investigation/venv/lib/python3.11/site-packages/openpyxl/workbook/child.py:99: UserWarning:
#
# Title is more than 31 characters. Some applications may not be able to read the file
#
# /var/folders/ld/px3lfl4j771_lns2jvpqcpfr0000gn/T/ipykernel_70128/862417038.py:60: FutureWarning:
#
# The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#
# /var/folders/ld/px3lfl4j771_lns2jvpqcpfr0000gn/T/ipykernel_70128/862417038.py:61: FutureWarning:
#
# The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#
# /var/folders/ld/px3lfl4j771_lns2jvpqcpfr0000gn/T/ipykernel_70128/862417038.py:62: FutureWarning:
#
# The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#
# /var/folders/ld/px3lfl4j771_lns2jvpqcpfr0000gn/T/ipykernel_70128/862417038.py:62: FutureWarning:
#
# The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#
# /var/folders/ld/px3lfl4j771_lns2jvpqcpfr0000gn/T/ipykernel_70128/862417038.py:60: FutureWarning:
#
# The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#
# /var/folders/ld/px3lfl4j771_lns2jvpqcpfr0000gn/T/ipykernel_70128/862417038.py:61: FutureWarning:
#
# The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#
# /var/folders/ld/px3lfl4j771_lns2jvpqcpfr0000gn/T/ipykernel_70128/862417038.py:62: FutureWarning:
#
# The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#
# /var/folders/ld/px3lfl4j771_lns2jvpqcpfr0000gn/T/ipykernel_70128/862417038.py:62: FutureWarning:
#
# The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#
# /var/folders/ld/px3lfl4j771_lns2jvpqcpfr0000gn/T/ipykernel_70128/862417038.py:60: FutureWarning:
#
# The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#
# /var/folders/ld/px3lfl4j771_lns2jvpqcpfr0000gn/T/ipykernel_70128/862417038.py:61: FutureWarning:
#
# The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#
# /var/folders/ld/px3lfl4j771_lns2jvpqcpfr0000gn/T/ipykernel_70128/862417038.py:62: FutureWarning:
#
# The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#
# /var/folders/ld/px3lfl4j771_lns2jvpqcpfr0000gn/T/ipykernel_70128/862417038.py:62: FutureWarning:
#
# The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
